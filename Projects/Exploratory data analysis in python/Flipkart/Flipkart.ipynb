# %% [markdown]
# # Mobile Phones

# %% [markdown]
# Mobile phones are one of the most rapidly rising industries, as well as one of
# the most prominent industries in the technology sector. The rate of increase has
# been exponential, with the number of mobile phone customers increasing
# fivefold in the last decade. Globally, the number of smartphones sold to end
# users climbed from 300 million in 2010 to 1.5 billion by 2020.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## To read the data

# %%
a=pd.read_csv("Flipkart.csv")

# %%
a
# Out:
#       brand           model base_color processor screen_size  ROM  RAM  \
# 0     Apple       iPhone SE      Black     Water  Very Small   64    2
# 1     Apple  iPhone 12 Mini        Red   Ceramic       Small   64    4
# 2     Apple       iPhone SE        Red     Water  Very Small   64    2
# 3     Apple       iPhone XR     Others       iOS      Medium   64    3
# 4     Apple       iPhone 12        Red   Ceramic      Medium  128    4
# ..      ...             ...        ...       ...         ...  ...  ...
# 425  Xiaomi     Redmi 6 Pro      Black  Qualcomm       Small   32    3
# 426  Xiaomi     Redmi 6 Pro        Red  Qualcomm       Small   64    4
# 427  Xiaomi      Mi 11 Lite     Others  Qualcomm       Large  128    6
# 428  Xiaomi   Redmi 8A Dual       Blue  Qualcomm      Medium   32    3
# 429  Xiaomi     Redmi 6 Pro       Blue  Qualcomm       Small   32    3
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# ...

# %%
a.shape
# Out:
# (430, 16)

# %% [markdown]
# ## Checking for null & Data type

# %%
a.isnull()
# Out:
#      brand  model  base_color  processor  screen_size    ROM    RAM  \
# 0    False  False       False      False        False  False  False
# 1    False  False       False      False        False  False  False
# 2    False  False       False      False        False  False  False
# 3    False  False       False      False        False  False  False
# 4    False  False       False      False        False  False  False
# ..     ...    ...         ...        ...          ...    ...    ...
# 425  False  False       False      False        False  False  False
# 426  False  False       False      False        False  False  False
# 427  False  False       False      False        False  False  False
# 428  False  False       False      False        False  False  False
# 429  False  False       False      False        False  False  False
#
#      display_size  num_rear_camera  num_front_camera  battery_capacity  \
# 0           False            False             False             False
# ...

# %%
a.isnull().sum()
# Out:
# brand               0
# model               0
# base_color          0
# processor           0
# screen_size         0
# ROM                 0
# RAM                 0
# display_size        0
# num_rear_camera     0
# num_front_camera    0
# battery_capacity    0
# ratings             0
# num_of_ratings      0
# sales_price         0
# discount_percent    0
# sales               0
# dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   brand             430 non-null    object
#  1   model             430 non-null    object
#  2   base_color        430 non-null    object
#  3   processor         430 non-null    object
#  4   screen_size       430 non-null    object
#  5   ROM               430 non-null    int64
#  6   RAM               430 non-null    int64
#  7   display_size      430 non-null    float64
#  8   num_rear_camera   430 non-null    int64
#  9   num_front_camera  430 non-null    int64
#  10  battery_capacity  430 non-null    int64
#  11  ratings           430 non-null    float64
#  12  num_of_ratings    430 non-null    int64
#  13  sales_price       430 non-null    int64
#  14  discount_percent  430 non-null    float64
#  15  sales             430 non-null    float64
# ...

# %% [markdown]
# ## To check duplicates

# %%
a.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## To know the stastical info

# %%
a.describe()
# Out:
#               ROM         RAM  displaysize     backcam    frontcam  \
# count  430.000000  430.000000   430.000000  430.000000  430.000000
# mean   105.748837    5.320930     6.369767    2.904651    1.044186
# std     63.164064    2.182635     0.369549    0.952350    0.227280
# min      8.000000    1.000000     4.700000    1.000000    1.000000
# 25%     64.000000    4.000000     6.300000    2.000000    1.000000
# 50%    128.000000    4.000000     6.500000    3.000000    1.000000
# 75%    128.000000    6.000000     6.500000    4.000000    1.000000
# max    512.000000   12.000000     7.600000    4.000000    3.000000
#
#        batterycapacity     ratings  Total ratings          price   discount%  \
# count       430.000000  430.000000     430.000000     430.000000  430.000000
# mean       4529.397674    4.339302   23567.944186   25433.234884    0.108000
# std         986.907252    0.151494   56096.277784   22471.926588    0.073432
# ...

# %% [markdown]
# ## To rename the columns

# %%
a.rename(columns={"base_color":"color","screen_size":"screensize","display_size":"displaysize","num_rear_camera":"backcam","num_front_camera":"frontcam","battery_capacity":"batterycapacity","num_of_ratings":"Total ratings","sales_price":"price","discount_percent":"discount%"},inplace=True)

# %%
a
# Out:
#       brand           model   color processor  screensize  ROM  RAM  \
# 0     Apple       iPhone SE   Black     Water  Very Small   64    2
# 1     Apple  iPhone 12 Mini     Red   Ceramic       Small   64    4
# 2     Apple       iPhone SE     Red     Water  Very Small   64    2
# 3     Apple       iPhone XR  Others       iOS      Medium   64    3
# 4     Apple       iPhone 12     Red   Ceramic      Medium  128    4
# ..      ...             ...     ...       ...         ...  ...  ...
# 425  Xiaomi     Redmi 6 Pro   Black  Qualcomm       Small   32    3
# 426  Xiaomi     Redmi 6 Pro     Red  Qualcomm       Small   64    4
# 427  Xiaomi      Mi 11 Lite  Others  Qualcomm       Large  128    6
# 428  Xiaomi   Redmi 8A Dual    Blue  Qualcomm      Medium   32    3
# 429  Xiaomi     Redmi 6 Pro    Blue  Qualcomm       Small   32    3
#
#      displaysize  backcam  frontcam  batterycapacity  ratings  Total ratings  \
# ...

# %% [markdown]
# ## To know the colunm names

# %%
a.columns
# Out:
# Index(['brand', 'model', 'color', 'processor', 'screensize', 'ROM', 'RAM',
#        'displaysize', 'backcam', 'frontcam', 'batterycapacity', 'ratings',
#        'Total ratings', 'price', 'discount%', 'sales'],
#       dtype='object')

# %% [markdown]
# ## To find top & bottom data

# %%
a.head()
# Out:
#    brand           model   color processor  screensize  ROM  RAM  displaysize  \
# 0  Apple       iPhone SE   Black     Water  Very Small   64    2          4.7
# 1  Apple  iPhone 12 Mini     Red   Ceramic       Small   64    4          5.4
# 2  Apple       iPhone SE     Red     Water  Very Small   64    2          4.7
# 3  Apple       iPhone XR  Others       iOS      Medium   64    3          6.1
# 4  Apple       iPhone 12     Red   Ceramic      Medium  128    4          6.1
#
#    backcam  frontcam  batterycapacity  ratings  Total ratings  price  \
# 0        1         1             1800      4.5          38645  32999
# 1        2         1             2815      4.5            244  57149
# 2        1         1             1800      4.5          38645  32999
# 3        1         1             2942      4.6           5366  42999
# 4        2         1             2815      4.6            745  69149
#
#    discount%   sales
# 0       0.17  127.52
# 1       0.04    1.39
# ...

# %%
a.tail()
# Out:
#       brand          model   color processor screensize  ROM  RAM  \
# 425  Xiaomi    Redmi 6 Pro   Black  Qualcomm      Small   32    3
# 426  Xiaomi    Redmi 6 Pro     Red  Qualcomm      Small   64    4
# 427  Xiaomi     Mi 11 Lite  Others  Qualcomm      Large  128    6
# 428  Xiaomi  Redmi 8A Dual    Blue  Qualcomm     Medium   32    3
# 429  Xiaomi    Redmi 6 Pro    Blue  Qualcomm      Small   32    3
#
#      displaysize  backcam  frontcam  batterycapacity  ratings  Total ratings  \
# 425          5.8        2         1             4000      4.3           1870
# 426          5.8        2         1             4000      4.3           1783
# 427          6.5        3         1             4250      4.2           1554
# 428          6.2        2         1             5000      4.2           8161
# 429          5.8        2         1             4000      4.3           1870
#
#      price  discount%  sales
# 425   7999       0.30   1.50
# 426   9699       0.28   1.73
# ...

# %% [markdown]
# ## To find the unique values of dataset

# %%
a.nunique()
# Out:
# brand                5
# model              119
# color               12
# processor            7
# screensize           5
# ROM                  7
# RAM                  7
# displaysize         17
# backcam              4
# frontcam             3
# batterycapacity     30
# ratings             10
# Total ratings      175
# price              141
# discount%           33
# sales              216
# dtype: int64

# %% [markdown]
# ## To collect the sample data

# %%
a.sample(10)
# Out:
#        brand             model  color processor screensize  ROM  RAM  \
# 211   Realme             8 Pro   Blue  Qualcomm     Medium  128    6
# 112   Realme               C20   Blue  MediaTek      Large   32    2
# 418   Xiaomi             Mi A1  Black  Qualcomm      Small   64    4
# 233   Realme                 7  White  MediaTek      Large   64    6
# 186   Realme                3i    Red  MediaTek     Medium   64    4
# 75      Poco            X3 Pro   Blue  Qualcomm      Large  128    8
# 345  Samsung        Galaxy F41  Black    Exynos     Medium   64    6
# 422   Xiaomi  Redmi Note 9 Pro   Blue  Qualcomm      Large  128    6
# 395   Xiaomi      Redmi Note 4   Gold  Qualcomm      Small   32    3
# 287  Samsung        Galaxy F62   Blue    Exynos      Large  128    6
#
#      displaysize  backcam  frontcam  batterycapacity  ratings  Total ratings  \
# 211          6.4        4         1             4500      4.3          10126
# ...

# %% [markdown]
# ## To fetch certain or particular range of data

# %%
a.loc[200:270]
# Out:
#        brand          model  color processor screensize  ROM  RAM  \
# 200   Realme   X3 SuperZoom   Blue  Qualcomm      Large  256   12
# 201   Realme   X3 SuperZoom  White  Qualcomm      Large  256   12
# 202   Realme   X3 SuperZoom  White  Qualcomm      Large  256    8
# 203   Realme              6   Blue  MediaTek      Large  128    8
# 204   Realme             6i  White  MediaTek      Large   64    4
# ..       ...            ...    ...       ...        ...  ...  ...
# 266  Samsung     Galaxy M02  Black  MediaTek      Large   32    2
# 267  Samsung  Galaxy A22 5G   Gray  MediaTek      Large  128    8
# 268  Samsung    Galaxy A21s  Black    Exynos      Large  128    6
# 269  Samsung    Galaxy A03s  Black  MediaTek      Large   64    4
# 270  Samsung     Galaxy M31  Black    Others     Medium  128    6
#
#      displaysize  backcam  frontcam  batterycapacity  ratings  Total ratings  \
# 200          6.6        4         2             4200      4.2            459
# ...

# %%
a.loc[20]
# Out:
# brand                       Apple
# model              iPhone 12 Mini
# color                      Purple
# processor                 Ceramic
# screensize                  Small
# ROM                           256
# RAM                             4
# displaysize                   5.4
# backcam                         2
# frontcam                        1
# batterycapacity              2815
# ratings                       4.5
# Total ratings                 244
# price                       72149
# discount%                    0.03
# sales                        1.76
# discount price           69984.53
# Name: 20, dtype: object

# %%
a.iloc[200:270]
# Out:
#        brand              model   color processor screensize  ROM  RAM  \
# 200   Realme       X3 SuperZoom    Blue  Qualcomm      Large  256   12
# 201   Realme       X3 SuperZoom   White  Qualcomm      Large  256   12
# 202   Realme       X3 SuperZoom   White  Qualcomm      Large  256    8
# 203   Realme                  6    Blue  MediaTek      Large  128    8
# 204   Realme                 6i   White  MediaTek      Large   64    4
# ..       ...                ...     ...       ...        ...  ...  ...
# 265  Samsung  Galaxy Z Flip3 5G  Others  Qualcomm      Large  256    8
# 266  Samsung         Galaxy M02   Black  MediaTek      Large   32    2
# 267  Samsung      Galaxy A22 5G    Gray  MediaTek      Large  128    8
# 268  Samsung        Galaxy A21s   Black    Exynos      Large  128    6
# 269  Samsung        Galaxy A03s   Black  MediaTek      Large   64    4
#
#      displaysize  backcam  frontcam  batterycapacity  ratings  Total ratings  \
# ...

# %%
a.iloc[20]
# Out:
# brand                       Apple
# model              iPhone 12 Mini
# color                      Purple
# processor                 Ceramic
# screensize                  Small
# ROM                           256
# RAM                             4
# displaysize                   5.4
# backcam                         2
# frontcam                        1
# batterycapacity              2815
# ratings                       4.5
# Total ratings                 244
# price                       72149
# discount%                    0.03
# sales                        1.76
# discount price           69984.53
# Name: 20, dtype: object

# %% [markdown]
# ## To find max,min & unique values

# %%
a["batterycapacity"].max()
# Out:
# 7000

# %%
a["batterycapacity"].min()
# Out:
# 1800

# %%
a["batterycapacity"].unique()
# Out:
# array([1800, 2815, 2942, 5000, 6000, 5160, 5065, 4000, 4500, 4300, 4310,
#        4035, 4230, 4200, 3300, 7000, 4400, 2600, 3000, 3400, 3700, 4800,
#        4520, 4030, 4250, 4820, 5020, 4100, 3080, 4780], dtype=int64)

# %%
a["price"].max()
# Out:
# 157999

# %%
a["price"].min()
# Out:
# 5742

# %%
a["price"].unique()
# Out:
# array([ 32999,  57149,  42999,  69149,  64149,  62149,  79149,  47999,
#         72149,  38999,  36999,   8999,  10999,   9999,   7999,  11999,
#         12999,  18999,  16499,  20999,  14499,  15999,  28999,  14999,
#         13999,  30999,  26999,  21999,  11499,  16999,  10499,   7499,
#          7299,   8799,  13499,  17999,  15499,  20149,  18499,  18149,
#         29999,  22149,  17149,  19999,  27999,  25999,  27149,  30149,
#         37999,   8499,   6499,  41999,   6999,  24999,   9499,   9569,
#          8278,  12499,  37499,  14750,  88999,   8238,  17499,  17599,
#         18666,  22499,  34225,  12176,  84999,  23999,  20288,  27499,
#         10986,  12390,  20696,  22990,  77999, 149999,   9299,   8850,
#        157999,  35999,  15199,  12400,  91999,  54599,  49999,   8083,
#         17990,   9490,  15299,   7990,  13800,  11490,  16980,  34999,
#         28490,  71999,  24499,  14090,  11599,  39999,  73999,  13695,
# ...

# %%
a["brand"].unique()
# Out:
# array(['Apple', 'Poco', 'Realme', 'Samsung', 'Xiaomi'], dtype=object)

# %%
a["color"].unique()
# Out:
# array(['Black', 'Red', 'Others', 'Blue', 'White', 'Green', 'Purple',
#        'Yellow', 'Gold', 'Bronze', 'Silver', 'Gray'], dtype=object)

# %%
a["model"].unique()
# Out:
# array(['iPhone SE', 'iPhone 12 Mini', 'iPhone XR', 'iPhone 12',
#        'iPhone 8', 'iPhone 7 Plus', 'C3', 'M3', 'M2 Reloaded', 'X3 Pro',
#        'M3 Pro 5G', 'M2 Pro', 'F3 GT', 'X3', 'F1', 'M2', 'X2', 'C20',
#        'C11 2021', 'C21Y', 'Narzo 30 5G', 'C21', 'Narzo 30', '8s 5G',
#        'Narzo 30A', '8 5G', '8 Pro', 'C15', '8', 'GT Master Edition',
#        'X7 5G', '7', 'Narzo 30 Pro 5G', 'C12', 'C11', 'X7 Max', 'GT 5G',
#        '5 Pro', '3i', 'Narzo 20 Pro', '7 Pro', 'X3 SuperZoom',
#        'X7 Pro 5G', 'C2', '6', '6i', 'C25', 'Narzo 20', 'Narzo 10A',
#        'Narzo 20A', 'Narzo 10', 'Galaxy F22', 'Galaxy F12', 'M02s',
#        'Galaxy M02', 'Galaxy A22', 'Galaxy A52s 5G', 'Galaxy M32',
#        'Galaxy Z Flip3 5G', 'Galaxy A22 5G', 'Galaxy A21s', 'Galaxy A03s',
#        'Galaxy M31', 'Galaxy A51', 'Galaxy A72', 'Galaxy A12',
#        'Galaxy F62', 'Galaxy A31', 'Galaxy A52', 'Galaxy F02s',
#        'Galaxy M11', 'Galaxy F41', 'Galaxy A71', 'Galaxy Note 20',
# ...

# %% [markdown]
# ## Pivot table

# %%
b=a.pivot_table("ratings",columns="brand",aggfunc="max")
b
# Out:
# brand    Apple  Poco  Realme  Samsung  Xiaomi
# ratings    4.6   4.6     4.5      4.6     4.5

# %%
b=a.pivot_table("ratings",columns="model",aggfunc="max")
b
# Out:
# model     3i  5 Pro    6   6i    7  7 Pro    8  8 5G  8 Pro  8s 5G  ...  \
# ratings  4.4    4.5  4.4  4.4  4.3    4.4  4.3   4.3    4.4    4.5  ...
#
# model    X3 SuperZoom  X7 5G  X7 Max  X7 Pro 5G  iPhone 12  iPhone 12 Mini  \
# ratings           4.3    4.3     4.3        4.3        4.6             4.5
#
# model    iPhone 7 Plus  iPhone 8  iPhone SE  iPhone XR
# ratings            4.5       4.5        4.5        4.6
#
# [1 rows x 119 columns]

# %%
b=a.pivot_table("price",columns=["brand","model"],aggfunc="sum")
b
# Out:
# brand     Apple                                                            \
# model iPhone 12 iPhone 12 Mini iPhone 7 Plus iPhone 8 iPhone SE iPhone XR
# price   1210533        1029384         36999    38999     98997    818982
#
# brand   Poco                        ...    Xiaomi                            \
# model     C3     F1   F3 GT     M2  ... Redmi K20 Redmi Note 4 Redmi Note 5
# price  50994  40998  173994  44996  ...     41819         8565        10999
#
# brand                                                                  \
# model Redmi Note 5 Pro Redmi Note 6 Pro Redmi Note 7 Redmi Note 7 Pro
# price            26900            64687        25198            89482
#
# brand
# model Redmi Note 9 Pro Redmi Y2 Redmi Y3
# price            64463     9499    33750
#
# [1 rows x 120 columns]

# %%
b=pd.pivot_table(data=a[["brand","model","price"]],index=["brand","model"],values="price",aggfunc="sum").sort_values(by="price")
b
# Out:
#                              price
# brand   model
# Xiaomi  Redmi 6A              5742
#         Redmi 5               6890
# Samsung Galaxy A10            7990
# Xiaomi  Redmi 9A              8394
#         Redmi Note 4          8565
# ...                            ...
# Samsung Galaxy Z Flip3 5G   347996
#         Galaxy Z Fold3 5G   457997
# Apple   iPhone XR           818982
#         iPhone 12 Mini     1029384
#         iPhone 12          1210533
#
# [120 rows x 1 columns]

# %%
e=pd.pivot_table(data=a[["brand","batterycapacity","price"]],index=["brand","batterycapacity"],values="price",aggfunc="min")
e.sort_values(by=["price"])
# Out:
#                           price
# brand   batterycapacity
# Xiaomi  3000               5742
# Realme  4000               6499
# Xiaomi  3300               6890
# Realme  5000               7299
# Samsung 3400               7990
# Poco    5000               7999
# Xiaomi  4000               7999
# Samsung 5000               8083
# Xiaomi  5000               8299
# Realme  4230               8499
# Xiaomi  4100               8565
# Realme  6000               8999
# Samsung 4000               8999
#         3000               9490
# Xiaomi  3080               9499
# Poco    6000              10999
# Samsung 6000              11499
# Xiaomi  4030              12990
# Realme  4300              12999
# Samsung 3300              13800
# Realme  4035              13999
# Xiaomi  5020              14199
# Realme  4500              14999
# Samsung 2600              15999
# Poco    4500              15999
#         5160              18999
#         4000              18999
# ...

# %% [markdown]
# ## To fetch particular brand data

# %%
c=a[a["brand"]=="Xiaomi"]
c.sort_values(by=["price"])
# Out:
#       brand          model  color processor screensize  ROM  RAM  displaysize  \
# 419  Xiaomi       Redmi 6A   Gold  MediaTek      Small   32    2          5.5
# 424  Xiaomi        Redmi 5   Blue  Qualcomm      Small   16    2          5.7
# 425  Xiaomi    Redmi 6 Pro  Black  Qualcomm      Small   32    3          5.8
# 429  Xiaomi    Redmi 6 Pro   Blue  Qualcomm      Small   32    3          5.8
# 423  Xiaomi       Redmi Y3    Red  Qualcomm     Medium   32    3          6.3
# ..      ...            ...    ...       ...        ...  ...  ...          ...
# 406  Xiaomi         Mi 10T  Black  Qualcomm      Large  128    6          6.7
# 399  Xiaomi         Mi 10T  Black  Qualcomm      Large  128    8          6.7
# 417  Xiaomi  Mi 11X Pro 5G  Black  Qualcomm      Large  128    8          6.7
# 400  Xiaomi     Mi 10T Pro  Black  Qualcomm      Large  128    8          6.7
# 408  Xiaomi          Mi 10  Green  Qualcomm      Large  256    8          6.7
#
# ...

# %%
d=a[a["brand"]=="Apple"]
d.sort_values(by=["price"])
# Out:
#     brand           model   color processor  screensize  ROM  RAM  \
# 0   Apple       iPhone SE   Black     Water  Very Small   64    2
# 2   Apple       iPhone SE     Red     Water  Very Small   64    2
# 35  Apple       iPhone SE   White     Water  Very Small   64    2
# 43  Apple   iPhone 7 Plus   Black       iOS       Small   32    2
# 42  Apple        iPhone 8    Gold       iOS  Very Small   64    2
# 53  Apple       iPhone XR    Blue     Water      Medium   64    3
# 50  Apple       iPhone XR    Blue       iOS      Medium   64    3
# 49  Apple       iPhone XR   Black     Water      Medium   64    3
# 48  Apple       iPhone XR   White     Water      Medium   64    3
# 47  Apple       iPhone XR   White       iOS      Medium   64    3
# 33  Apple       iPhone XR   Black       iOS      Medium   64    3
# 54  Apple       iPhone XR  Yellow       iOS      Medium   64    3
# 27  Apple       iPhone XR  Others     Water      Medium   64    3
# ...

# %%
d1=a.groupby(['brand'])['price'].max()
d1
# Out:
# brand
# Apple       79149
# Poco        30999
# Realme      41999
# Samsung    157999
# Xiaomi      54999
# Name: price, dtype: int64

# %%
d1=a.groupby(['brand','model'])['price'].max()
d1.sort_values(ascending=False)
# Out:
# brand    model
# Samsung  Galaxy Z Fold3 5G          157999
#          Galaxy Fold 2              149999
#          Galaxy Note 20 Ultra 5G     91999
#          Galaxy Z Flip3 5G           88999
# Apple    iPhone 12                   79149
#                                      ...
# Realme   C20                          7499
#          C2                           7499
#          C11                          7499
# Xiaomi   Redmi 5                      6890
#          Redmi 6A                     5742
# Name: price, Length: 120, dtype: int64

# %%
a["brand"].value_counts()
# Out:
# Realme     138
# Samsung    119
# Xiaomi      61
# Apple       56
# Poco        56
# Name: brand, dtype: int64

# %% [markdown]
# ## To find discount price

# %%
a["discount price"] = a["price"] - (a["discount%"] * a["price"])
a["discount price"]
# Out:
# 0      27389.17
# 1      54863.04
# 2      27389.17
# 3      38699.10
# 4      67766.02
#          ...
# 425     5599.30
# 426     6983.28
# 427    19359.12
# 428     7718.07
# 429     5241.60
# Name: discount price, Length: 430, dtype: float64

# %%
a
# Out:
#       brand           model   color processor  screensize  ROM  RAM  \
# 0     Apple       iPhone SE   Black     Water  Very Small   64    2
# 1     Apple  iPhone 12 Mini     Red   Ceramic       Small   64    4
# 2     Apple       iPhone SE     Red     Water  Very Small   64    2
# 3     Apple       iPhone XR  Others       iOS      Medium   64    3
# 4     Apple       iPhone 12     Red   Ceramic      Medium  128    4
# ..      ...             ...     ...       ...         ...  ...  ...
# 425  Xiaomi     Redmi 6 Pro   Black  Qualcomm       Small   32    3
# 426  Xiaomi     Redmi 6 Pro     Red  Qualcomm       Small   64    4
# 427  Xiaomi      Mi 11 Lite  Others  Qualcomm       Large  128    6
# 428  Xiaomi   Redmi 8A Dual    Blue  Qualcomm      Medium   32    3
# 429  Xiaomi     Redmi 6 Pro    Blue  Qualcomm       Small   32    3
#
#      displaysize  backcam  frontcam  batterycapacity  ratings  Total ratings  \
# ...

# %% [markdown]
# # To reset the data columns

# %%
z=pd.DataFrame(a.groupby(["brand","color","processor","RAM","batterycapacity"])["price","discount price","discount%"].max().reset_index())
z
# Out:
#       brand  color processor  RAM  batterycapacity  price  discount price  \
# 0     Apple  Black   Ceramic    4             2815  79149        77566.02
# 1     Apple  Black     Water    2             1800  32999        27389.17
# 2     Apple  Black     Water    3             2942  47999        43679.09
# 3     Apple  Black       iOS    2             1800  36999        36259.02
# 4     Apple  Black       iOS    3             2942  47999        43679.09
# ..      ...    ...       ...  ...              ...    ...             ...
# 282  Xiaomi  White  Qualcomm    3             5000   8299         7718.07
# 283  Xiaomi  White  Qualcomm    4             4030  12990        11301.30
# 284  Xiaomi  White  Qualcomm    4             5020  16487        15992.39
# 285  Xiaomi  White  Qualcomm    6             4000  20920        20083.20
# 286  Xiaomi  White  Qualcomm    6             4520  24398        22934.12
#
#      discount%
# 0         0.04
# 1         0.17
# 2         0.10
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Plot a graph discount Vs brand

# %%
plt.bar(a['brand'],a['discount%'])
plt.title('discount Vs brand',fontsize=15,color='red')
plt.xlabel('brand',fontsize=15)
plt.ylabel('discount',fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.bar('brand','discount%', data=a,color='green')
plt.show()

# %% [markdown]
# # countplot

# %%
print(a['model'].value_counts())
plt.figure(figsize=(18,5))
sns.countplot(x=a['model'])
plt.xticks(rotation=90)
plt.show()
# Out:
# iPhone XR            18
# iPhone 12            17
# iPhone 12 Mini       16
# GT Master Edition     9
# X3                    9
#                      ..
# Galaxy A7             1
# Galaxy Fold 2         1
# Galaxy M11            1
# 6i                    1
# Redmi 5               1
# Name: model, Length: 119, dtype: int64

# %%
print(a['brand'].value_counts())
plt.figure(figsize=(12,6))
sns.countplot(y=a['brand'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Realme     138
# Samsung    119
# Xiaomi      61
# Apple       56
# Poco        56
# Name: brand, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.title('model wise product count')
sns.barplot(x='model',y='Sales',data=a,hue='Segment',palette='coolwarm_r')
plt.xlabel('Region',fontsize=15)
plt.show()

# %%
sns.countplot(x='brand',data=a,palette='coolwarm')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='batterycapacity',data=a,palette='tab10')
plt.show()

# %% [markdown]
# ## relplot

# %%
sns.relplot(x='discount%',y='price',hue='brand',data=a)
plt.show()

# %% [markdown]
# ## pieplot

# %%
plt.title('brand',fontsize=20)
a['brand'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.title('RAM',fontsize=20)
a['RAM'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# ## barplot

# %%
a.groupby('brand')[['price','batterycapacity']].sum().plot.bar(color=['red','blue'],figsize=(8,5))
plt.ylabel('price and batterycapacity')
plt.show()

# %%
plt.figure(figsize=(18,15))
plt.title('discount wise price in each brand')
sns.barplot(x='brand',y='price',data=a,hue='discount%',order=a['brand'].value_counts().index,palette='coolwarm_r')
plt.xlabel('brand',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('discount wise price in each brand')
sns.barplot(x='brand',y='price',data=c,hue='discount%',palette='coolwarm_r')
plt.xlabel('brand',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.title('discount wise price in each brand')
sns.barplot(x='brand',y='price',data=d,hue='discount%',palette='coolwarm_r')
plt.xlabel('brand',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.countplot(x="model",data=a,palette='rocket_r',order=a['model'].value_counts().index)
plt.xlabel('model',fontsize=25)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# ## heatmap

# %%
n=['price','batterycapacity','discount%','discount price']
plt.figure(figsize=(10,7))
sns.heatmap(a[n].corr(),annot=True,fmt='.4f',cmap='coolwarm_r',center=0)
plt.show()

# %% [markdown]
# ## lineplot

# %%
plt.figure(figsize = (10,4))
sns.lineplot('discount%', 'brand', data = a, color = 'r', label= 'discount%')
plt.legend()
plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.figure(figsize = (12,5))
sns.boxplot(x='brand',y='price',data=a)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (12,5))
sns.boxplot(x='price',y='brand',data=a)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Scatterplot

# %%
plt.figure(figsize=(8,5))
plt.scatter(x='brand',y='price',data=a)
plt.xlabel('Brand')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(x='batterycapacity',y='price',data=a)
plt.xlabel('batterycapacity')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ## histogram

# %%
a.hist(bins=20 ,figsize=(20,15),color='blue')
plt.show()

# %%
sns.pairplot(a, hue="brand", diag_kind="hist")
plt.show()

# %% [markdown]
# ## pairplot

# %%
sns.pairplot(a,hue='brand')
plt.show()

# %%
sns.pairplot(a)
plt.show()

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# According to the data, most phones sold are in the price range of 15,000 to
# 20,000. Poco, Xiaomi, and Realme have done well to capture the market in this
# segment. It is recommended that the vendor have phones from all these
# companies in this price range..They've done their homework and are
# concentrating on the processor, display size, and colour that Indian consumers
# desire.
#
# People in India is changing their buying patterns, and they now want to buy
# branded and high-end products. So, if the seller decides to sell Apple or
# Samsung Mobile, he may see an increase in sales and revenue over time, but it
# will be difficult to gain customers quickly in the current situation. The risk will
# also be substantial because the profit margin is unknown and the investment to
# be made is high.
