# %% [markdown]
# ## Company data

# %% [markdown]
# **Import Libries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# **Read the dataset**

# %%
d=pd.read_csv('Company.csv')
d
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# **Data Exploration**

# %%
d.shape
# Out:
# (14999, 10)

# %%
d.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Sales_Occured            0
# salary                   0
# dtype: int64

# %%
d.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Sales_Occured', 'salary'],
#       dtype='object')

# %%
d.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                   3              0     1                      0
# 1                   6              0     1                      0
# 2                   4              0     1                      0
# 3                   5              0     1                      0
# 4                   3              0     1                      0
#
#   Sales_Occured  salary
# 0         sales     low
# 1         sales  medium
# 2         sales  medium
# ...

# %%
d.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Sales_Occured salary
# 14994                      0       support    low
# 14995                      0       support    low
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Sales_Occured          14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
d.describe().T
# Out:
#                          count        mean        std    min     25%     50%  \
# satisfaction_level     14999.0    0.612834   0.248631   0.09    0.44    0.64
# last_evaluation        14999.0    0.716102   0.171169   0.36    0.56    0.72
# number_project         14999.0    3.803054   1.232592   2.00    3.00    4.00
# average_montly_hours   14999.0  201.050337  49.943099  96.00  156.00  200.00
# time_spend_company     14999.0    3.498233   1.460136   2.00    3.00    3.00
# Work_accident          14999.0    0.144610   0.351719   0.00    0.00    0.00
# left                   14999.0    0.238083   0.425924   0.00    0.00    0.00
# promotion_last_5years  14999.0    0.021268   0.144281   0.00    0.00    0.00
#
#                           75%    max
# satisfaction_level       0.82    1.0
# last_evaluation          0.87    1.0
# number_project           5.00    7.0
# average_montly_hours   245.00  310.0
# time_spend_company       4.00   10.0
# Work_accident            0.00    1.0
# ...

# %%
d.duplicated().sum()
# Out:
# 3008

# %%
d.rename({'satisfaction_level':'satisfaction','last_evaluation':'lastevaluation','average_montly_hours':'montlyhours','time_spend_company':'timespend','Work_accident':'Workaccident','promotion_last_5years':'promotions','Sales_Occured':'Sales'},axis=1,inplace=True)

# %%
d
# Out:
#        satisfaction  lastevaluation  number_project  montlyhours  timespend  \
# 0              0.38            0.53               2          157          3
# 1              0.80            0.86               5          262          6
# 2              0.11            0.88               7          272          4
# 3              0.72            0.87               5          223          5
# 4              0.37            0.52               2          159          3
# ...             ...             ...             ...          ...        ...
# 14994          0.40            0.57               2          151          3
# 14995          0.37            0.48               2          160          3
# 14996          0.37            0.53               2          143          3
# 14997          0.11            0.96               6          280          4
# 14998          0.37            0.52               2          158          3
#
#        Workaccident  left  promotions    Sales  salary
# ...

# %% [markdown]
# **Data Extraction**

# %%
d['Sales'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
d[d['salary']=='low']
# Out:
#        satisfaction  lastevaluation  number_project  montlyhours  timespend  \
# 0              0.38            0.53               2          157          3
# 3              0.72            0.87               5          223          5
# 4              0.37            0.52               2          159          3
# 5              0.41            0.50               2          153          3
# 6              0.10            0.77               6          247          4
# ...             ...             ...             ...          ...        ...
# 14994          0.40            0.57               2          151          3
# 14995          0.37            0.48               2          160          3
# 14996          0.37            0.53               2          143          3
# 14997          0.11            0.96               6          280          4
# 14998          0.37            0.52               2          158          3
#
#        Workaccident  left  promotions    Sales salary
# ...

# %%
d[d['salary']=='high']
# Out:
#        satisfaction  lastevaluation  number_project  montlyhours  timespend  \
# 72             0.45            0.49               2          149          3
# 111            0.09            0.85               6          289          4
# 189            0.44            0.51               2          156          3
# 267            0.45            0.53               2          129          3
# 306            0.37            0.46               2          149          3
# ...             ...             ...             ...          ...        ...
# 14829          0.45            0.57               2          148          3
# 14868          0.43            0.55               2          130          3
# 14902          0.45            0.46               2          159          3
# 14941          0.43            0.49               2          131          3
# 14980          0.76            0.89               5          238          5
#
# ...

# %%
d[d['salary']=='medium']
# Out:
#        satisfaction  lastevaluation  number_project  montlyhours  timespend  \
# 1              0.80            0.86               5          262          6
# 2              0.11            0.88               7          272          4
# 60             0.85            0.91               5          226          5
# 61             0.11            0.93               7          308          4
# 62             0.10            0.95               6          244          5
# ...             ...             ...             ...          ...        ...
# 14979          0.09            0.93               6          296          4
# 14982          0.38            0.49               2          137          3
# 14983          0.72            0.84               5          257          5
# 14984          0.40            0.56               2          148          3
# 14985          0.91            0.99               5          254          5
#
# ...

# %%
d[['timespend','salary','promotions']][(d['timespend']>5)&(d['salary']=='low')&(d['promotions']==1)]
# Out:
#        timespend salary  promotions
# 11215          8    low           1
# 11220          6    low           1
# 11275          6    low           1
# 11276          6    low           1
# 11730          7    low           1
# 13426          8    low           1
# 13431          6    low           1
# 13486          6    low           1
# 13487          6    low           1
# 13941          7    low           1

# %%
d[['timespend','salary','promotions']][(d['timespend']>5)&(d['salary']=='medium')&(d['promotions']==1)]
# Out:
#        timespend  salary  promotions
# 4541           6  medium           1
# 5031           6  medium           1
# 5055           6  medium           1
# 5115           6  medium           1
# 11185          6  medium           1
# 11213          6  medium           1
# 11216          8  medium           1
# 11217          8  medium           1
# 11218          8  medium           1
# 11219          6  medium           1
# 11270          7  medium           1
# 11271          7  medium           1
# 11272          7  medium           1
# 11273          7  medium           1
# 11274          7  medium           1
# 11725          7  medium           1
# 11726          7  medium           1
# 11728          7  medium           1
# 11760         10  medium           1
# 13396          6  medium           1
# 13424          6  medium           1
# 13427          8  medium           1
# 13428          8  medium           1
# 13429          8  medium           1
# ...

# %%
best=d[['timespend','salary','promotions']][(d['timespend']>5)&(d['salary']=='high')&(d['promotions']==1)]
best
# Out:
#        timespend salary  promotions
# 5524           6   high           1
# 11214          8   high           1
# 11729          7   high           1
# 11755          7   high           1
# 11756          7   high           1
# 11757          7   high           1
# 11758          7   high           1
# 11935          7   high           1
# 11936          7   high           1
# 11937          7   high           1
# 11938          7   high           1
# 11940         10   high           1
# 11993         10   high           1
# 11994         10   high           1
# 11995         10   high           1
# 11996         10   high           1
# 11997         10   high           1
# 11998         10   high           1
# 13425          8   high           1
# 13940          7   high           1
# 13966          7   high           1
# 13967          7   high           1
# 13968          7   high           1
# 13969          7   high           1
# 14146          7   high           1
# ...

# %%
d['salary']=d['salary'].replace({'low':0,'medium':1,'high':2})

# %%
d.head()
# Out:
#    satisfaction  lastevaluation  number_project  montlyhours  timespend  \
# 0          0.38            0.53               2          157          3
# 1          0.80            0.86               5          262          6
# 2          0.11            0.88               7          272          4
# 3          0.72            0.87               5          223          5
# 4          0.37            0.52               2          159          3
#
#    Workaccident  left  promotions  Sales  salary
# 0             0     1           0  sales       0
# 1             0     1           0  sales       1
# 2             0     1           0  sales       1
# 3             0     1           0  sales       0
# 4             0     1           0  sales       0

# %%
d.drop(['lastevaluation','Workaccident'],axis=1,inplace=True)

# %%
d.dtypes
# Out:
# satisfaction      float64
# number_project      int64
# montlyhours         int64
# timespend           int64
# left                int64
# promotions          int64
# Sales              object
# salary              int64
# dtype: object

# %%
d['Sales'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
d['Sales']=d['Sales'].replace({'sales':1, 'accounting':2, 'hr':3, 'technical':4, 'support':5, 'management':6,
       'IT':7, 'product_mng':8, 'marketing':9, 'RandD':10})

# %%
d1=d.copy()

# %% [markdown]
# **Data Visuallization**

# %%
plt.bar(d1['salary'],d1['montlyhours'])
plt.title('montlyhours Vs salary',fontsize=15,color='red')
plt.ylabel('montlyhours',fontsize=15)
plt.xlabel('salary',fontsize=15)
plt.grid(True)
plt.show()

# %%
print(d1['left'].value_counts())
plt.figure(figsize=(10,4))
sns.countplot(x=d1['left'])
plt.xticks(rotation=90)
plt.show()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
sns.relplot(x='timespend',y='number_project',hue='left',data=d1)
plt.show()

# %%
plt.title('salary',fontsize=20)
d1['salary'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.title('left',fontsize=20)
d1['left'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
n_data=['satisfaction','salary','timespend','left']
plt.figure(figsize=(10,5))
sns.heatmap(d1[n_data].corr(),annot=True,fmt='.4f',cmap='coolwarm_r',center=0)
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.lineplot('salary','satisfaction',data=d1,color='r',label='salary')
plt.legend()
plt.show()

# %%
x=d.drop(['salary'],axis=1)
x
# Out:
#        satisfaction  number_project  montlyhours  timespend  left  promotions  \
# 0              0.38               2          157          3     1           0
# 1              0.80               5          262          6     1           0
# 2              0.11               7          272          4     1           0
# 3              0.72               5          223          5     1           0
# 4              0.37               2          159          3     1           0
# ...             ...             ...          ...        ...   ...         ...
# 14994          0.40               2          151          3     1           0
# 14995          0.37               2          160          3     1           0
# 14996          0.37               2          143          3     1           0
# 14997          0.11               6          280          4     1           0
# 14998          0.37               2          158          3     1           0
#
#        Sales
# 0          1
# ...

# %%
y=d.salary
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        0
# 4        0
#         ..
# 14994    0
# 14995    0
# 14996    0
# 14997    0
# 14998    0
# Name: salary, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=20)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (10499, 7) (4500, 7) (10499,) (4500,)

# %%
from sklearn.metrics import *
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import *
import xgboost as xgb
import time

# %%
def model_create(model, x_train, y_train, x_test, y_test):
    i_time=time.time()
    model.fit(x_train,y_train)
    model.score(x_test,y_test)
    y_predict=model.predict(x_test)
    acc_s=accuracy_score(y_test,y_predict)
    t=time.time()-i_time
    print('Time Taken: {}'.format(t))
    print('accuracy score: {}'.format(acc_s))
    print(classification_report(y_test,y_predict))
    plot_confusion_matrix(model, x_test, y_test)
    return model, acc_s,t

# %%
model_LR=LogisticRegression()
model_LR, accuracy_LR,t= model_create(model_LR, x_train, y_train, x_test, y_test)
# Out:
# Time Taken: 0.35135960578918457
# accuracy score: 0.4911111111111111
#               precision    recall  f1-score   support
#
#            0       0.55      0.50      0.52      2226
#            1       0.44      0.58      0.50      1900
#            2       0.00      0.00      0.00       374
#
#     accuracy                           0.49      4500
#    macro avg       0.33      0.36      0.34      4500
# weighted avg       0.46      0.49      0.47      4500

# %%
model_RF=RandomForestClassifier()
model_RF, accuracy_RF,t= model_create(model_RF, x_train, y_train, x_test, y_test)
# Out:
# Time Taken: 1.0862879753112793
# accuracy score: 0.6022222222222222
#               precision    recall  f1-score   support
#
#            0       0.63      0.66      0.64      2226
#            1       0.57      0.60      0.59      1900
#            2       0.59      0.28      0.38       374
#
#     accuracy                           0.60      4500
#    macro avg       0.60      0.51      0.54      4500
# weighted avg       0.60      0.60      0.60      4500

# %%
model_DC=DecisionTreeClassifier()
model_DC, accuracy_DC,t= model_create(model_DC, x_train, y_train, x_test, y_test)
# Out:
# Time Taken: 0.03750729560852051
# accuracy score: 0.572
#               precision    recall  f1-score   support
#
#            0       0.63      0.62      0.62      2226
#            1       0.57      0.56      0.56      1900
#            2       0.30      0.34      0.32       374
#
#     accuracy                           0.57      4500
#    macro avg       0.50      0.51      0.50      4500
# weighted avg       0.58      0.57      0.57      4500

# %%
model_KN=KNeighborsClassifier()
model_KN, accuracy_KN,t= model_create(model_KN, x_train, y_train, x_test, y_test)
# Out:
# Time Taken: 0.22573328018188477
# accuracy score: 0.5071111111111111
#               precision    recall  f1-score   support
#
#            0       0.54      0.63      0.58      2226
#            1       0.47      0.46      0.46      1900
#            2       0.26      0.04      0.07       374
#
#     accuracy                           0.51      4500
#    macro avg       0.42      0.37      0.37      4500
# weighted avg       0.49      0.51      0.49      4500

# %%
model_AB=AdaBoostClassifier(n_estimators=50,learning_rate=1)
model_AB,accuracy_AB,t_AB= model_create(model_AB, x_train, y_train, x_test, y_test)
# Out:
# Time Taken: 0.27310967445373535
# accuracy score: 0.5084444444444445
#               precision    recall  f1-score   support
#
#            0       0.53      0.76      0.62      2226
#            1       0.46      0.31      0.37      1900
#            2       0.72      0.05      0.09       374
#
#     accuracy                           0.51      4500
#    macro avg       0.57      0.37      0.36      4500
# weighted avg       0.51      0.51      0.47      4500

# %%
model_ABC=AdaBoostClassifier(base_estimator=RandomForestClassifier(n_estimators=100),n_estimators=50,learning_rate=1)
model_ABC,accuracy_ABC,t_ABC= model_create(model_ABC, x_train, y_train, x_test, y_test)
# Out:
# Time Taken: 100.98557949066162
# accuracy score: 0.6
#               precision    recall  f1-score   support
#
#            0       0.62      0.66      0.64      2226
#            1       0.57      0.59      0.58      1900
#            2       0.61      0.28      0.38       374
#
#     accuracy                           0.60      4500
#    macro avg       0.60      0.51      0.54      4500
# weighted avg       0.60      0.60      0.59      4500

# %%
model_BC= BaggingClassifier(base_estimator=RandomForestClassifier(),n_estimators=100,max_samples=0.8,oob_score=True,random_state=1)
model_BC,accuracy_BC,t_BC= model_create(model_BC, x_train, y_train, x_test, y_test)
# Out:
# Time Taken: 236.40336513519287
# accuracy score: 0.5917777777777777
#               precision    recall  f1-score   support
#
#            0       0.61      0.67      0.64      2226
#            1       0.56      0.58      0.57      1900
#            2       0.81      0.22      0.34       374
#
#     accuracy                           0.59      4500
#    macro avg       0.66      0.49      0.52      4500
# weighted avg       0.60      0.59      0.58      4500

# %%
model_XG=xgb.XGBClassifier()
model_XG,accuracy_XG,t_XG= model_create(model_XG, x_train, y_train, x_test, y_test)
# Out:
# Time Taken: 1.1326637268066406
# accuracy score: 0.5671111111111111
#               precision    recall  f1-score   support
#
#            0       0.59      0.65      0.62      2226
#            1       0.53      0.55      0.54      1900
#            2       0.64      0.18      0.28       374
#
#     accuracy                           0.57      4500
#    macro avg       0.59      0.46      0.48      4500
# weighted avg       0.57      0.57      0.56      4500
